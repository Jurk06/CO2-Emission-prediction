# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab
from matplotlib.pylab import rcParams
#rcParams['figure.figsize']=20,16

# %%
df=pd.read_csv('D:\\python\\Titanic_ML\\co2_emission\\MER_T12_06.csv')

# %%
df.shape
# Out:
# (5094, 6)

# %%
df.head()
# Out:
#        MSN  YYYYMM   Value  Column_Order  \
# 0  CLEIEUS  197301  72.076             1
# 1  CLEIEUS  197302  64.442             1
# 2  CLEIEUS  197303  64.084             1
# 3  CLEIEUS  197304  60.842             1
# 4  CLEIEUS  197305  61.798             1
#
#                                 Description  \
# 0  Coal Electric Power Sector CO2 Emissions
# 1  Coal Electric Power Sector CO2 Emissions
# 2  Coal Electric Power Sector CO2 Emissions
# 3  Coal Electric Power Sector CO2 Emissions
# 4  Coal Electric Power Sector CO2 Emissions
#
#                                     Unit
# 0  Million Metric Tons of Carbon Dioxide
# 1  Million Metric Tons of Carbon Dioxide
# 2  Million Metric Tons of Carbon Dioxide
# 3  Million Metric Tons of Carbon Dioxide
# 4  Million Metric Tons of Carbon Dioxide

# %%
date=lambda x: pd.to_datetime(x, format='%Y%m', errors='coerce')
df=pd.read_csv('D:\\python\\Titanic_ML\\co2_emission\\MER_T12_06.csv', parse_dates=['YYYYMM'], index_col='YYYYMM', date_parser=date)

# %%
df.head(15)
# Out:
#                 MSN    Value  Column_Order  \
# YYYYMM
# 1973-01-01  CLEIEUS   72.076             1
# 1973-02-01  CLEIEUS   64.442             1
# 1973-03-01  CLEIEUS   64.084             1
# 1973-04-01  CLEIEUS   60.842             1
# 1973-05-01  CLEIEUS   61.798             1
# 1973-06-01  CLEIEUS   66.538             1
# 1973-07-01  CLEIEUS   72.626             1
# 1973-08-01  CLEIEUS   75.181             1
# 1973-09-01  CLEIEUS   68.397             1
# 1973-10-01  CLEIEUS   67.668             1
# 1973-11-01  CLEIEUS   67.021             1
# 1973-12-01  CLEIEUS   71.118             1
# NaT         CLEIEUS  811.791             1
# 1974-01-01  CLEIEUS    70.55             1
# 1974-02-01  CLEIEUS   62.929             1
#
#                                          Description  \
# YYYYMM
# 1973-01-01  Coal Electric Power Sector CO2 Emissions
# 1973-02-01  Coal Electric Power Sector CO2 Emissions
# 1973-03-01  Coal Electric Power Sector CO2 Emissions
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5094 entries, 1973-01-01 to 2016-07-01
# Data columns (total 5 columns):
# MSN             5094 non-null object
# Value           5094 non-null object
# Column_Order    5094 non-null int64
# Description     5094 non-null object
# Unit            5094 non-null object
# dtypes: int64(1), object(4)
# memory usage: 238.8+ KB

# %%
df['Value']=pd.to_numeric(df['Value'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5094 entries, 1973-01-01 to 2016-07-01
# Data columns (total 5 columns):
# MSN             5094 non-null object
# Value           4678 non-null float64
# Column_Order    5094 non-null int64
# Description     5094 non-null object
# Unit            5094 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 238.8+ KB

# %%
df.dropna(inplace=True)

# %%
df.head(10)
# Out:
#                 MSN   Value  Column_Order  \
# YYYYMM
# 1973-01-01  CLEIEUS  72.076             1
# 1973-02-01  CLEIEUS  64.442             1
# 1973-03-01  CLEIEUS  64.084             1
# 1973-04-01  CLEIEUS  60.842             1
# 1973-05-01  CLEIEUS  61.798             1
# 1973-06-01  CLEIEUS  66.538             1
# 1973-07-01  CLEIEUS  72.626             1
# 1973-08-01  CLEIEUS  75.181             1
# 1973-09-01  CLEIEUS  68.397             1
# 1973-10-01  CLEIEUS  67.668             1
#
#                                          Description  \
# YYYYMM
# 1973-01-01  Coal Electric Power Sector CO2 Emissions
# 1973-02-01  Coal Electric Power Sector CO2 Emissions
# 1973-03-01  Coal Electric Power Sector CO2 Emissions
# 1973-04-01  Coal Electric Power Sector CO2 Emissions
# 1973-05-01  Coal Electric Power Sector CO2 Emissions
# 1973-06-01  Coal Electric Power Sector CO2 Emissions
# 1973-07-01  Coal Electric Power Sector CO2 Emissions
# ...

# %%
df1=df.groupby('Description')

# %%
df1.head()
# Out:
#                 MSN    Value  Column_Order  \
# YYYYMM
# 1973-01-01  CLEIEUS   72.076             1
# 1973-02-01  CLEIEUS   64.442             1
# 1973-03-01  CLEIEUS   64.084             1
# 1973-04-01  CLEIEUS   60.842             1
# 1973-05-01  CLEIEUS   61.798             1
# 1973-01-01  NNEIEUS   12.175             2
# 1973-02-01  NNEIEUS   11.708             2
# 1973-03-01  NNEIEUS   13.994             2
# 1973-04-01  NNEIEUS   14.627             2
# 1973-05-01  NNEIEUS   17.344             2
# 1973-01-01  DKEIEUS    2.375             3
# 1973-02-01  DKEIEUS    2.061             3
# 1973-03-01  DKEIEUS    1.171             3
# 1973-04-01  DKEIEUS    1.022             3
# 1973-05-01  DKEIEUS    0.949             3
# 1973-01-01  PCEIEUS    0.128             4
# 1973-02-01  PCEIEUS    0.106             4
# 1973-03-01  PCEIEUS    0.083             4
# 1973-04-01  PCEIEUS    0.130             4
# 1973-05-01  PCEIEUS    0.167             4
# ...

# %%
ff=df[df['Description']=='Coal Electric Power Sector CO2 Emissions']

# %%
plt.figure(figsize=(10,5))
ff.plot(grid=True, figsize=(15,5))
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.show()

# %%
f1=df[df['Description']=='Natural Gas Electric Power Sector CO2 Emissions']

# %%
f1.plot(grid=True, figsize=(15,8), kind='line')
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.legend(labels=["Natural Gas", "Column_Order"], fontsize=15)
plt.show()

# %%
f2=df[df['Description']=='Distillate Fuel, Including Kerosene-Type Jet Fuel, Oil Electric Power Sector CO2 Emissions']

# %%
f2.plot(grid=True, figsize=(15,8))
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.legend(labels=["Distillate Fuel", "Column_Order"], fontsize=15)
plt.show()

# %%
df.Description.value_counts()
# Out:
# Total Energy Electric Power Sector CO2 Emissions                                              566
# Natural Gas Electric Power Sector CO2 Emissions                                               566
# Distillate Fuel, Including Kerosene-Type Jet Fuel, Oil Electric Power Sector CO2 Emissions    566
# Petroleum Electric Power Sector CO2 Emissions                                                 566
# Petroleum Coke Electric Power Sector CO2 Emissions                                            566
# Coal Electric Power Sector CO2 Emissions                                                      566
# Residual Fuel Oil Electric Power Sector CO2 Emissions                                         566
# Non-Biomass Waste Electric Power Sector CO2 Emissions                                         358
# Geothermal Energy Electric Power Sector CO2 Emissions                                         358
# Name: Description, dtype: int64

# %%
f3=df[df['Description']=='Petroleum Electric Power Sector CO2 Emissions']

# %%
f3.plot(grid=True, figsize=(15,5))
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.legend(labels=["Petroleum Electric Power", "Column_Order"], fontsize=15)
plt.show()

# %%
f4=df[df['Description']=='Petroleum Coke Electric Power Sector CO2 Emissions']

# %%
f4.plot(grid=True, figsize=(15,8))
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.legend(labels=["Petroleum Coke Electric Power Secto", "Column_Order"], fontsize=10)
plt.show()

# %%
f5=df[df['Description']=='Coal Electric Power Sector CO2 Emissions']

# %%
f5.plot(grid=True, figsize=(15,8))
plt.xlabel("Monthly")
plt.ylabel("Co2 emission")
plt.legend(labels=["Coal Electric Power Sector CO2 Emissions", "Column_Order"], fontsize=10)
plt.show()

# %%
f6=df[df['Description']=='Residual Fuel Oil Electric Power Sector CO2 Emissions']
f7=df[df['Description']=='Non-Biomass Waste Electric Power Sector CO2 Emissions']
f8=df[df['Description']=='Geothermal Energy Electric Power Sector CO2 Emissions']

# %%
f6.plot(grid=True, figsize=(15, 8))
f7.plot(grid=True, figsize=(15,8))
f8.plot(grid=True, figsize=(15,8))
plt.legend(labels=["F3"])
plt.legend(labels=["F3"])
plt.legend(labels=["F3"])

# %%
fig, ax=plt.subplots(figsize=(10,5))
plt.bar(df1, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-ba941d8ff939> in <module>()
#       1 fig, ax=plt.subplots(figsize=(10,5))
# ----> 2 plt.bar(df1)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2768                       mplDeprecation)
#    2769     try:
# -> 2770         ret = ax.bar(*args, **kwargs)
#    2771     finally:
#    2772         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
# ...
